# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Benign Data

# %%
db1 = pd.read_csv('benign_2013_1.csv')
db1['year']='January 2013'
db2 = pd.read_csv('benign_2013_2.csv')
db2['year']='February 2013'
db3 = pd.read_csv('benign_2013_3.csv')
db3['year']='March 2013'
db4 = pd.read_csv('benign_2013_4.csv')
db4['year']='April 2013'
db5 = pd.read_csv('benign_2013_5.csv')
db5['year']='May 2013'
db6 = pd.read_csv('benign_2013_6.csv')
db6['year']='June 2013'
db7 = pd.read_csv('benign_2013_7.csv')
db7['year']='July 2013'
db8 = pd.read_csv('benign_2013_8.csv')
db8['year']='August 2013'
db9 = pd.read_csv('benign_2013_9.csv')
db9['year']='September 2013'
db10 = pd.read_csv('benign_2013_10.csv')
db10['year']='October 2013'
db11 = pd.read_csv('benign_2013_11.csv')
db11['year']='November 2013'
db12 = pd.read_csv('benign_2013_12.csv')
db12['year']='December 2013'
db13 = pd.read_csv('benign_2014_1.csv')
db13['year']='January 2014'
db14 = pd.read_csv('benign_2014_2.csv')
db14['year']='February 2014'
db15 = pd.read_csv('benign_2014_3.csv')
db15['year']='March 2014'
db16 = pd.read_csv('benign_2014_4.csv')
db16['year']='April 2014'
db17 = pd.read_csv('benign_2014_5.csv')
db17['year']='May 2014'
db18 = pd.read_csv('benign_2014_6.csv')
db18['year']='June 2014'
db19 = pd.read_csv('benign_2014_7.csv')
db19['year']='July 2014'

# %% [markdown]
# # Merging the benign dataset

# %%
combined = db1
combined = combined.append([db2,db3,db4,db5,db6,db7,db8,db9,db10,db11,db12,db13,db14,db15,db16,db17,db18,db19])
combined=pd.DataFrame(combined)
combined.head()
# Out:
#    username      revid               revtime  \
# 0  Swiftscw  535365129  2013-01-28T16:43:56Z
# 1  Swiftscw  535365309  2013-01-28T16:45:08Z
# 2  Swiftscw  535366071  2013-01-28T16:50:17Z
# 3  Swiftscw  535369287  2013-01-28T17:13:40Z
# 4  Swiftscw  535370277  2013-01-28T17:21:30Z
#
#                            pagetitle  isReverted revertTime  cluebotRevert  \
# 0                      User:Swiftscw       False          -              0
# 1                      User:Swiftscw       False          -              0
# 2                      User:Swiftscw       False          -              0
# 3       User:Swiftscw/AMAPOLA CABASE       False          -              0
# 4  Wikipedia:Requests for undeletion       False          -              0
#
#    stiki_score  stiki_REP_USER          year
# 0          0.0             0.0  January 2013
# 1          0.0             0.0  January 2013
# 2          0.0             0.0  January 2013
# 3          0.0             0.0  January 2013
# 4          0.0             0.0  January 2013

# %% [markdown]
# # Reading user file

# %%
colnames = ['username','userid','blocked_time','blocked_reason','type']
type(colnames)
users=pd.read_table('users.tsv',sep="\t",header=None,names=colnames)
users=pd.DataFrame(users)
users.head()
# Out:
#        username    userid blocked_time blocked_reason    type
# 0      Swiftscw  18342896            -              -  benign
# 1         Azkle  18359941            -              -  benign
# 2    Tgrosinger  18228795            -              -  benign
# 3  BanglarBogra  18197517            -              -  benign
# 4     Tiny Trot  18315964            -              -  benign

# %% [markdown]
# # Benign and User Left Join on "username"

# %%
ben = pd.merge(combined,users,how='left',on='username')
ben.head(10)
# Out:
#    username      revid               revtime  \
# 0  Swiftscw  535365129  2013-01-28T16:43:56Z
# 1  Swiftscw  535365309  2013-01-28T16:45:08Z
# 2  Swiftscw  535366071  2013-01-28T16:50:17Z
# 3  Swiftscw  535369287  2013-01-28T17:13:40Z
# 4  Swiftscw  535370277  2013-01-28T17:21:30Z
# 5  Swiftscw  535376382  2013-01-28T18:07:16Z
# 6  Swiftscw  535379254  2013-01-28T18:27:12Z
# 7  Swiftscw  535380411  2013-01-28T18:34:51Z
# 8  Swiftscw  535382439  2013-01-28T18:48:17Z
# 9  Swiftscw  535390355  2013-01-28T19:40:51Z
#
#                            pagetitle  isReverted revertTime  cluebotRevert  \
# 0                      User:Swiftscw       False          -              0
# 1                      User:Swiftscw       False          -              0
# 2                      User:Swiftscw       False          -              0
# 3       User:Swiftscw/AMAPOLA CABASE       False          -              0
# 4  Wikipedia:Requests for undeletion       False          -              0
# 5                       Maria Cabase       False          -              0
# 6                       Maria Cabase       False          -              0
# 7                       Maria Cabase       False          -              0
# 8                       Maria Cabase       False          -              0
# 9                       Maria Cabase       False          -              0
#
#    stiki_score  stiki_REP_USER          year    userid blocked_time  \
# 0     0.000000             0.0  January 2013  18342896            -
# 1     0.000000             0.0  January 2013  18342896            -
# 2     0.000000             0.0  January 2013  18342896            -
# 3     0.000000             0.0  January 2013  18342896            -
# 4     0.000000             0.0  January 2013  18342896            -
# 5     0.292556             0.0  January 2013  18342896            -
# 6     0.282316             0.0  January 2013  18342896            -
# 7     0.367025             0.0  January 2013  18342896            -
# 8     0.282316             0.0  January 2013  18342896            -
# 9     0.132504             0.0  January 2013  18342896            -
#
#   blocked_reason    type
# 0              -  benign
# 1              -  benign
# 2              -  benign
# 3              -  benign
# 4              -  benign
# 5              -  benign
# 6              -  benign
# 7              -  benign
# 8              -  benign
# 9              -  benign

# %% [markdown]
# # Reading Vandal data

# %%
dv1 = pd.read_csv('vandal_2013_1.csv')
dv1['year']='January 2013'
dv2 = pd.read_csv('vandal_2013_2.csv')
dv2['year']='February 2013'
dv3 = pd.read_csv('vandal_2013_3.csv')
dv3['year']='March 2013'
dv4 = pd.read_csv('vandal_2013_4.csv')
dv4['year']='April 2013'
dv5 = pd.read_csv('vandal_2013_5.csv')
dv5['year']='May 2013'
dv6 = pd.read_csv('vandal_2013_6.csv')
dv6['year']='June 2013'
dv7 = pd.read_csv('vandal_2013_7.csv')
dv7['year']='July 2013'
dv8 = pd.read_csv('vandal_2013_8.csv')
dv8['year']='August 2013'
dv9 = pd.read_csv('vandal_2013_9.csv')
dv9['year']='September 2013'
dv10 = pd.read_csv('vandal_2013_10.csv')
dv10['year']='October 2013'
dv11 = pd.read_csv('vandal_2013_11.csv')
dv11['year']='November 2013'
dv12 = pd.read_csv('vandal_2013_12.csv')
dv12['year']='December 2013'
dv13 = pd.read_csv('vandal_2014_1.csv')
dv13['year']='January 2014'
dv14 = pd.read_csv('vandal_2014_2.csv')
dv14['year']='February 2014'
dv15 = pd.read_csv('vandal_2014_3.csv')
dv15['year']='March 2014'
dv16 = pd.read_csv('vandal_2014_4.csv')
dv16['year']='April 2014'
dv17 = pd.read_csv('vandal_2014_5.csv')
dv17['year']='May 2014'
dv18 = pd.read_csv('vandal_2014_6.csv')
dv18['year']='June 2014'
dv19 = pd.read_csv('vandal_2014_7.csv')
dv19['year']='July 2014'

# %% [markdown]
# # Merging the Vandal dataset

# %%
comvandal = dv1
comvandal = comvandal.append([dv2,dv3,dv4,dv5,dv6,dv7,dv8,dv9,dv10,dv11,dv12,dv13,dv14,dv15,dv16,dv17,dv18,dv19])
comvandal=pd.DataFrame(comvandal)
comvandal.head()
# Out:
#       username        revid               revtime      pagetitle isReverted  \
# 0  Alex12rocks  535937612.0  2013-01-31T23:19:17Z  Pueblo Revolt       True
# 1  Alex12rocks  535937732.0  2013-01-31T23:20:04Z  Pueblo Revolt       True
# 2  Alex12rocks  535937933.0  2013-01-31T23:21:19Z  Pueblo Revolt       True
# 3  Alex12rocks  535938394.0  2013-01-31T23:24:08Z  Pueblo Revolt       True
# 4  Alex12rocks  535938540.0  2013-01-31T23:24:56Z  Pueblo Revolt       True
#
#              revertTime  cluebotRevert  stiki_score  stiki_REP_USER  \
# 0  2013-01-31T23:20:35Z            0.0     0.462073        0.000000
# 1  2013-01-31T23:20:35Z            0.0     0.437085        0.000000
# 2  2013-01-31T23:21:30Z            0.0     0.648625        0.999851
# 3  2013-01-31T23:24:15Z            0.0     0.439547        1.999305
# 4  2013-01-31T23:24:59Z            1.0     0.618692        2.998948
#
#            year
# 0  January 2013
# 1  January 2013
# 2  January 2013
# 3  January 2013
# 4  January 2013

# %% [markdown]
# # Vandal and User Left Join on "username"

# %%
van = pd.merge(comvandal,users,how='left',on='username')
van.head()
# Out:
#       username        revid               revtime      pagetitle isReverted  \
# 0  Alex12rocks  535937612.0  2013-01-31T23:19:17Z  Pueblo Revolt       True
# 1  Alex12rocks  535937732.0  2013-01-31T23:20:04Z  Pueblo Revolt       True
# 2  Alex12rocks  535937933.0  2013-01-31T23:21:19Z  Pueblo Revolt       True
# 3  Alex12rocks  535938394.0  2013-01-31T23:24:08Z  Pueblo Revolt       True
# 4  Alex12rocks  535938540.0  2013-01-31T23:24:56Z  Pueblo Revolt       True
#
#              revertTime  cluebotRevert  stiki_score  stiki_REP_USER  \
# 0  2013-01-31T23:20:35Z            0.0     0.462073        0.000000
# 1  2013-01-31T23:20:35Z            0.0     0.437085        0.000000
# 2  2013-01-31T23:21:30Z            0.0     0.648625        0.999851
# 3  2013-01-31T23:24:15Z            0.0     0.439547        1.999305
# 4  2013-01-31T23:24:59Z            1.0     0.618692        2.998948
#
#            year     userid          blocked_time  \
# 0  January 2013  4232100.0  2013-01-31T23:34:10Z
# 1  January 2013  4232100.0  2013-01-31T23:34:10Z
# 2  January 2013  4232100.0  2013-01-31T23:34:10Z
# 3  January 2013  4232100.0  2013-01-31T23:34:10Z
# 4  January 2013  4232100.0  2013-01-31T23:34:10Z
#
#                                       blocked_reason    type
# 0  [[WP:Vandalism-only account|Vandalism-only acc...  vandal
# 1  [[WP:Vandalism-only account|Vandalism-only acc...  vandal
# 2  [[WP:Vandalism-only account|Vandalism-only acc...  vandal
# 3  [[WP:Vandalism-only account|Vandalism-only acc...  vandal
# 4  [[WP:Vandalism-only account|Vandalism-only acc...  vandal

# %% [markdown]
# # Reading Page Details Data

# %%
pages=pd.read_csv('pages.tsv')
pages=pd.DataFrame(pages)
pages.head(10)
# Out:
#                                  pagetitle    pageid  \
# 0                            User:Swiftscw  38354683
# 1             User:Swiftscw/AMAPOLA CABASE  38354972
# 2        Wikipedia:Requests for undeletion  26803395
# 3                             Maria Cabase  32754928
# 4                        Talk:Maria Cabase  34549656
# 5                    Manuel Kabajar Cabase  32755116
# 6              User talk:Postdlf/Archive23  38090775
# 7  Wikipedia:WikiProject Biography/Members   6163553
# 8                       User talk:Swiftscw  40011085
# 9                           Bobby Enriquez   7040405
#
#                                       pagecategories
# 0  set([u'Category:WikiProject Biography particip...
# 1                                            set([])
# 2  set([u'Category:Wikipedia maintenance', u'Cate...
# 3  set([u'Category:Filipino pianists', u'Category...
# 4  set([u'Category:WikiProject Biography articles...
# 5  set([u'Category:Filipino drummers', u'Category...
# 6                                            set([])
# 7                                            set([])
# 8                                            set([])
# 9  set([u'Category:Filipino Pentecostals', u'Cate...

# %% [markdown]
# # Left Join Vandal and Benign with Page data on "pagetitle"

# %%
van_final = pd.merge(van,pages,how='left',on="pagetitle")
ben_final = pd.merge(ben,pages,how='left',on="pagetitle")
van_final.head(10)
ben_final.head(10)
# Out:
#    username      revid               revtime  \
# 0  Swiftscw  535365129  2013-01-28T16:43:56Z
# 1  Swiftscw  535365309  2013-01-28T16:45:08Z
# 2  Swiftscw  535366071  2013-01-28T16:50:17Z
# 3  Swiftscw  535369287  2013-01-28T17:13:40Z
# 4  Swiftscw  535370277  2013-01-28T17:21:30Z
# 5  Swiftscw  535370277  2013-01-28T17:21:30Z
# 6  Swiftscw  535376382  2013-01-28T18:07:16Z
# 7  Swiftscw  535379254  2013-01-28T18:27:12Z
# 8  Swiftscw  535380411  2013-01-28T18:34:51Z
# 9  Swiftscw  535382439  2013-01-28T18:48:17Z
#
#                            pagetitle  isReverted revertTime  cluebotRevert  \
# 0                      User:Swiftscw       False          -              0
# 1                      User:Swiftscw       False          -              0
# 2                      User:Swiftscw       False          -              0
# 3       User:Swiftscw/AMAPOLA CABASE       False          -              0
# 4  Wikipedia:Requests for undeletion       False          -              0
# 5  Wikipedia:Requests for undeletion       False          -              0
# 6                       Maria Cabase       False          -              0
# 7                       Maria Cabase       False          -              0
# 8                       Maria Cabase       False          -              0
# 9                       Maria Cabase       False          -              0
#
#    stiki_score  stiki_REP_USER          year    userid blocked_time  \
# 0     0.000000             0.0  January 2013  18342896            -
# 1     0.000000             0.0  January 2013  18342896            -
# 2     0.000000             0.0  January 2013  18342896            -
# 3     0.000000             0.0  January 2013  18342896            -
# 4     0.000000             0.0  January 2013  18342896            -
# 5     0.000000             0.0  January 2013  18342896            -
# 6     0.292556             0.0  January 2013  18342896            -
# 7     0.282316             0.0  January 2013  18342896            -
# 8     0.367025             0.0  January 2013  18342896            -
# 9     0.282316             0.0  January 2013  18342896            -
#
#   blocked_reason    type    pageid  \
# 0              -  benign  38354683
# 1              -  benign  38354683
# 2              -  benign  38354683
# 3              -  benign  38354972
# 4              -  benign  26803395
# 5              -  benign  26803395
# 6              -  benign  32754928
# 7              -  benign  32754928
# 8              -  benign  32754928
# 9              -  benign  32754928
#
#                                       pagecategories
# 0  set([u'Category:WikiProject Biography particip...
# 1  set([u'Category:WikiProject Biography particip...
# 2  set([u'Category:WikiProject Biography particip...
# 3                                            set([])
# 4  set([u'Category:Wikipedia maintenance', u'Cate...
# 5  set([u'Category:Wikipedia maintenance', u'Cate...
# 6  set([u'Category:Filipino pianists', u'Category...
# 7  set([u'Category:Filipino pianists', u'Category...
# 8  set([u'Category:Filipino pianists', u'Category...
# 9  set([u'Category:Filipino pianists', u'Category...

# %% [markdown]
# # Cleaning the data

# %%
import pandas as pd

# %%
van_final.apply(lambda x: sum(x.isna()))
# Out:
# username          1066
# revid             1066
# revtime           1066
# pagetitle         1066
# isReverted        1066
# revertTime        1066
# cluebotRevert     1066
# stiki_score       1066
# stiki_REP_USER    1793
# year                 0
# userid            1066
# blocked_time      1066
# blocked_reason    1066
# type              1066
# pageid            1070
# pagecategories    1070
# dtype: int64

# %%
users_van = van_final.dropna(axis=0)
users_van.apply(lambda x: sum(x.isna()))
# Out:
# username          0
# revid             0
# revtime           0
# pagetitle         0
# isReverted        0
# revertTime        0
# cluebotRevert     0
# stiki_score       0
# stiki_REP_USER    0
# year              0
# userid            0
# blocked_time      0
# blocked_reason    0
# type              0
# pageid            0
# pagecategories    0
# dtype: int64

# %%
users_ben = ben_final.dropna(axis=0)
users_ben.apply(lambda x: sum(x.isna()))
# Out:
# username          0
# revid             0
# revtime           0
# pagetitle         0
# isReverted        0
# revertTime        0
# cluebotRevert     0
# stiki_score       0
# stiki_REP_USER    0
# year              0
# userid            0
# blocked_time      0
# blocked_reason    0
# type              0
# pageid            0
# pagecategories    0
# dtype: int64

# %% [markdown]
# # Merging Vandal and Benign Data

# %%
users_fin=users_van.append(users_ben)
users_fin.head()
# Out:
#       username        revid               revtime      pagetitle isReverted  \
# 0  Alex12rocks  535937612.0  2013-01-31T23:19:17Z  Pueblo Revolt       True
# 1  Alex12rocks  535937732.0  2013-01-31T23:20:04Z  Pueblo Revolt       True
# 2  Alex12rocks  535937933.0  2013-01-31T23:21:19Z  Pueblo Revolt       True
# 3  Alex12rocks  535938394.0  2013-01-31T23:24:08Z  Pueblo Revolt       True
# 4  Alex12rocks  535938540.0  2013-01-31T23:24:56Z  Pueblo Revolt       True
#
#              revertTime  cluebotRevert  stiki_score  stiki_REP_USER  \
# 0  2013-01-31T23:20:35Z            0.0     0.462073        0.000000
# 1  2013-01-31T23:20:35Z            0.0     0.437085        0.000000
# 2  2013-01-31T23:21:30Z            0.0     0.648625        0.999851
# 3  2013-01-31T23:24:15Z            0.0     0.439547        1.999305
# 4  2013-01-31T23:24:59Z            1.0     0.618692        2.998948
#
#            year     userid          blocked_time  \
# 0  January 2013  4232100.0  2013-01-31T23:34:10Z
# 1  January 2013  4232100.0  2013-01-31T23:34:10Z
# 2  January 2013  4232100.0  2013-01-31T23:34:10Z
# 3  January 2013  4232100.0  2013-01-31T23:34:10Z
# 4  January 2013  4232100.0  2013-01-31T23:34:10Z
#
#                                       blocked_reason    type    pageid  \
# 0  [[WP:Vandalism-only account|Vandalism-only acc...  vandal  569572.0
# 1  [[WP:Vandalism-only account|Vandalism-only acc...  vandal  569572.0
# 2  [[WP:Vandalism-only account|Vandalism-only acc...  vandal  569572.0
# 3  [[WP:Vandalism-only account|Vandalism-only acc...  vandal  569572.0
# 4  [[WP:Vandalism-only account|Vandalism-only acc...  vandal  569572.0
#
#                                       pagecategories
# 0  set([u'Category:17th century in New Spain', u'...
# 1  set([u'Category:17th century in New Spain', u'...
# 2  set([u'Category:17th century in New Spain', u'...
# 3  set([u'Category:17th century in New Spain', u'...
# 4  set([u'Category:17th century in New Spain', u'...

# %%
users_fin.columns
# Out:
# Index(['username', 'revid', 'revtime', 'pagetitle', 'isReverted', 'revertTime',
#        'cluebotRevert', 'stiki_score', 'stiki_REP_USER', 'year', 'userid',
#        'blocked_time', 'blocked_reason', 'type', 'pageid', 'pagecategories'],
#       dtype='object')

# %% [markdown]
# # Encoding "isReverted"

# %%
users_fin['isRevertEn'] = users_fin['isReverted'].apply(lambda x: int(x==True))

# %% [markdown]
# # Input and Target Variable
# ### 'isRevertEn' 'cluebotRevert' 'stiki_score' 'stiki_REP_USER'  are taken into consideration for building the model
#
# ### "type" is target variable that is predicted by the model

# %%
X = users_fin[['isRevertEn','cluebotRevert','stiki_score','stiki_REP_USER']]
y = users_fin['type']

# %% [markdown]
# ### From Scikit-Learn Importing train_test_split function
# ### Splitting input and target data into train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### From Scikit-Learn importing Logistic Regression Function

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Building Logistic Regression Model

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Predicting the Target Variable using the model build above

# %%
ypred = lr.predict(X_test)

# %% [markdown]
# ### From Scikit-Learn Importing Confusion_matrix and Accuracy

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %% [markdown]
# ### Comparing Actual and Predicted Target values using Confusion_Matrix

# %%
confusion_matrix(y_test,ypred)
# Out:
# array([[202239,  15072],
#        [ 16447,  45297]], dtype=int64)

# %% [markdown]
# ### Calculating Accuracy

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.8870509397788966
